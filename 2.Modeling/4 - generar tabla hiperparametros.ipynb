# %%
import pandas as pd

# %%
tabla_hp = pd.read_csv("tabla hiperparametros.csv")
tabla_hp
# Out:
#                Modelo            Hiper parámetro                 Valores  \
# 0            N-gramas          Rango de n-gramas  (1, 1), (2, 2), (3, 3)
# 1            N-gramas  Cantidad máxima de tokens                50, None
# 2            N-gramas          Máxima frecuencia                 1, 0.95
# 3            N-gramas          Mínima frecuencia                 0, 0.05
# 4              TF-IDF  Cantidad máxima de tokens                50, None
# 5              TF-IDF          Máxima frecuencia                 1, 0.95
# 6              TF-IDF          Mínima frecuencia                 0, 0.05
# 7   TF-IDF + n-gramas          Rango de n-gramas          (2, 2), (3, 3)
# 8   TF-IDF + n-gramas  Cantidad máxima de tokens                50, None
# 9   TF-IDF + n-gramas          Máxima frecuencia                 1, 0.95
# 10  TF-IDF + n-gramas          Mínima frecuencia                 0, 0.05
# 11                SVM                          C              0.1, 1 ,10
# ...

# %%
table_in_latex = None
with pd.option_context("max_colwidth", 1000):
    table_in_latex = tabla_hp.to_latex(index=False)

table_in_latex = table_in_latex.replace("\\\\", "\\\\ \\hline")
print(table_in_latex)
# Out:
# \begin{tabular}{llll}
# \toprule
#            Modelo &           Hiper parámetro &                Valores &                                                                                                                                              Descripción \\ \hline
# \midrule
#          N-gramas &         Rango de n-gramas & (1, 1), (2, 2), (3, 3) &               Cantidad de palabras utilizados para construir los n-gramas, por ejemplo, (1, 3) especifica que se extraerán 1-gramas, 2-gramas y 3-gramas \\ \hline
#          N-gramas & Cantidad máxima de tokens &               50, None &                                                                                    Cantidad máxima de tokens a extraer. Si es None, esta no se restringe \\ \hline
#          N-gramas &         Máxima frecuencia &                1, 0.95 &                                                                 Eliminar los tokens que aparezcan en un porcentaje superior de documentos al establecido \\ \hline
# ...
